# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

#reading the csv
dataframe = pd.read_csv('gsearch_jobs.csv', header=0, sep=',')
dataframe.head()
# Out:
#    Unnamed: 0  index                                             title  \
# 0           0      0                                      Data Analyst
# 1           1      1                                      Data Analyst
# 2           2      2                         Aeronautical Data Analyst
# 3           3      3  Data Analyst - Consumer Goods - Contract to Hire
# 4           4      4               Data Analyst | Workforce Management
#
#                  company_name            location           via  \
# 0                        Meta           Anywhere   via LinkedIn
# 1                         ATC    United States     via LinkedIn
# 2  Garmin International, Inc.       Olathe, KS       via Indeed
# 3                      Upwork           Anywhere     via Upwork
# 4                Krispy Kreme    United States     via LinkedIn
#
#                                          description  \
# 0  In the intersection of compliance and analytic...
# 1  Job Title: Entry Level Business Analyst / Prod...
# 2  Overview:\n\nWe are seeking a full-time...\nAe...
# 3  Enthusiastic Data Analyst for processing sales...
# 4  Overview of Position\n\nThis position will be ...
#
#                                           extensions  \
# 0  ['15 hours ago', '101K–143K a year', 'Work fro...
# 1  ['12 hours ago', 'Full-time', 'Health insurance']
# 2                      ['18 hours ago', 'Full-time']
# 3  ['12 hours ago', '15–25 an hour', 'Work from h...
# 4   ['7 hours ago', '90K–110K a year', 'Contractor']
#
#                                               job_id  \
# 0  eyJqb2JfdGl0bGUiOiJEYXRhIEFuYWx5c3QiLCJodGlkb2...
# 1  eyJqb2JfdGl0bGUiOiJEYXRhIEFuYWx5c3QiLCJodGlkb2...
# 2  eyJqb2JfdGl0bGUiOiJBZXJvbmF1dGljYWwgRGF0YSBBbm...
# 3  eyJqb2JfdGl0bGUiOiJEYXRhIEFuYWx5c3QgLSBDb25zdW...
# 4  eyJqb2JfdGl0bGUiOiJEYXRhIEFuYWx5c3QgfCBXb3JrZm...
#
#                                            thumbnail  ... commute_time  \
# 0  https://encrypted-tbn0.gstatic.com/images?q=tb...  ...          NaN
# 1  https://encrypted-tbn0.gstatic.com/images?q=tb...  ...          NaN
# 2                                                NaN  ...          NaN
# 3                                                NaN  ...          NaN
# 4  https://encrypted-tbn0.gstatic.com/images?q=tb...  ...          NaN
#
#   salary_pay salary_rate salary_avg salary_min salary_max salary_hourly  \
# 0  101K–143K      a year   122000.0   101000.0   143000.0           NaN
# 1        NaN         NaN        NaN        NaN        NaN           NaN
# 2        NaN         NaN        NaN        NaN        NaN           NaN
# 3      15–25     an hour       20.0       15.0       25.0          20.0
# 4   90K–110K      a year   100000.0    90000.0   110000.0           NaN
#
#    salary_yearly salary_standardized  \
# 0       122000.0            122000.0
# 1            NaN                 NaN
# 2            NaN                 NaN
# 3            NaN             41600.0
# 4       100000.0            100000.0
#
#                            description_tokens
# 0           ['sql', 'python', 'r', 'tableau']
# 1                                          []
# 2                                     ['sql']
# 3         ['power_bi', 'excel', 'powerpoint']
# 4  ['word', 'outlook', 'excel', 'powerpoint']
#
# [5 rows x 27 columns]

# %%
salary_statistic = dataframe[['salary_avg', 'salary_min', 'salary_max']].describe()
salary_statistic
# Out:
#           salary_avg     salary_min     salary_max
# count    7789.000000    7373.000000    7373.000000
# mean    37211.312559   31060.218911   44375.032531
# std     52592.271933   43912.486930   62479.379378
# min         7.250000       8.000000      10.000000
# 25%        30.500000      18.460000      44.000000
# 50%        57.500000      40.000000      75.000000
# 75%     87500.000000   75000.000000  100000.000000
# max    300000.000000  275000.000000  346000.000000

# %%
skills = dataframe['description_tokens']
skills_count = skills.value_counts()
top_skills = skills_count.head(15)
top_skills
# Out:
# description_tokens
# []                                             9247
# ['excel']                                      1649
# ['sql']                                        1566
# ['sql', 'excel']                                821
# ['tableau']                                     307
# ['sql', 'tableau']                              284
# ['go']                                          279
# ['power_bi', 'excel']                           276
# ['sql', 'microstrategy', 'jira', 'tableau']     272
# ['power_bi']                                    269
# ['python']                                      264
# ['power_bi', 'python']                          246
# ['sql', 'excel', 'tableau']                     230
# ['sql', 'python']                               225
# ['spreadsheet']                                 225
# Name: count, dtype: int64

# %%
via = dataframe['via']
via_count = via.value_counts()
top_via = via_count.head(15)
top_via
# Out:
# via
# via LinkedIn             16485
# via Upwork                6533
# via BeBee                 5377
# via Trabajo.org           3017
# via ZipRecruiter          2433
# via Indeed                1681
# via Snagajob               938
# via Jobs Trabajo.org       810
# via Adzuna                 659
# via Built In               370
# via Jora                   345
# via Monster                338
# via Ai-Jobs.net            307
# via My ArkLaMiss Jobs      283
# via SimplyHired            232
# Name: count, dtype: int64

# %%
company = dataframe['company_name']
company_count = company.value_counts()
top_company = company_count.head(15)
top_company
# Out:
# company_name
# Upwork                              6555
# Talentify.io                        1447
# Walmart                             1443
# EDWARD JONES                         746
# Corporate                            612
# Dice                                 586
# Cox Communications                   527
# Insight Global                       392
# Centene Corporation                  219
# Staffigo Technical Services, LLC     167
# Harnham                              145
# Saint Louis County Clerks Office     137
# CareerBuilder                        136
# Apex Systems                         126
# State of Missouri                    119
# Name: count, dtype: int64

# %%
stype = dataframe['schedule_type']
stype_count = stype.value_counts()
top_stype = stype_count.head(15)
top_stype
# Out:
# schedule_type
# Full-time                               32612
# Contractor                               7890
# Contractor and Temp work                 2311
# Full-time and Part-time                   527
# Part-time                                 476
# Internship                                299
# Full-time and Contractor                  224
# Full-time and Temp work                   177
# Full-time and Internship                  144
# Temp work                                 138
# Full-time, Part-time, and Internship       88
# Full-time, Contractor, and Temp work       57
# Part-time, Contractor, and Temp work       29
# Part-time and Contractor                   28
# Volunteer                                  23
# Name: count, dtype: int64

# %%
location = dataframe['location'].str.strip()
location_count = location.value_counts()
top_location = location_count.head(15)
top_location
# Out:
# location
# Anywhere              21015
# United States         12343
# Kansas City, MO        1249
# Oklahoma City, OK      1234
# Jefferson City, MO      854
# Bentonville, AR         513
# Tulsa, OK               459
# Wichita, KS             430
# Topeka, KS              369
# Overland Park, KS       368
# Springfield, MO         315
# Columbia, MO            287
# Springdale, AR          189
# California, MO          176
# Kansas City, KS         175
# Name: count, dtype: int64

# %%
work_from_home = dataframe['work_from_home']
work_from_home_count = work_from_home.value_counts()
work_from_home_count
# Out:
# work_from_home
# True    21015
# Name: count, dtype: int64

# %%
work_from_home = dataframe['work_from_home']
len(work_from_home)
# Out:
# 45275

# %%
hourly_salary = dataframe[dataframe['salary_hourly'].notnull()]
yearly_salary = dataframe[dataframe['salary_yearly'].notnull()]

hourly_salary_statistic = hourly_salary[['salary_avg', 'salary_min', 'salary_max']].describe()
yearly_salary_statistic = yearly_salary[['salary_avg', 'salary_min', 'salary_max']].describe()
hourly_salary_statistic, yearly_salary_statistic
# Out:
# (        salary_avg   salary_min   salary_max
#  count  4915.000000  4635.000000  4635.000000
#  mean     41.398125    29.622824    53.350365
#  std      22.892114    18.745180    31.143900
#  min       7.250000     8.000000    10.000000
#  25%      23.750000    16.570000    30.000000
#  50%      34.000000    20.000000    47.000000
#  75%      57.500000    40.000000    75.000000
#  max     300.000000   200.000000   500.000000,
#            salary_avg     salary_min     salary_max
#  count    2850.000000    2716.000000    2716.000000
#  mean   101562.219002   84217.971863  120294.603612
#  std     32054.390678   27571.694111   38339.064577
#  min     29289.840000   27519.630000   35000.000000
#  25%     80000.000000   68150.000000   94035.000000
#  50%     96500.000000   77000.000000  116000.000000
#  75%    113000.000000   93553.250000  135000.000000
#  max    300000.000000  275000.000000  346000.000000)

# %%
plt.figure(figsize=(15, 5))
plt.hist(dataframe['salary_hourly'])
plt.title('Distribution of Hour Salaries')
plt.xlabel('Hour Salary ($)')
plt.ylabel('Number of Job Postings')
plt.grid(axis='y', linestyle='--')
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(15, 5))
plt.hist(dataframe['salary_hourly'])
plt.title('Distribution of Hour Salaries')
plt.xlabel('Hour Salary ($)')
plt.ylabel('Number of Job Postings')
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(15, 5))
plt.hist(dataframe['salary_yearly'])
plt.title('Distribution of Year Salaries')
plt.xlabel('Year Salary ($)')
plt.ylabel('Number of Job Postings')
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(15, 5))
location_count.head(10).plot(kind='bar')
plt.title('Top 10 Locations')
plt.xlabel('Location')
plt.ylabel('Number of Job Postings')
plt.xticks(rotation=0)
plt.tight_layout()
plt.show()

# %%
work_from_home = dataframe['work_from_home']
work_from_home_count = work_from_home.value_counts()
null_value = sum(pd.isnull(dataframe['work_from_home']))
work_from_home_count, null_value
# Out:
# (work_from_home
#  True    21015
#  Name: count, dtype: int64,
#  24260)

# %%
plt.figure(figsize=(15, 5))
company_count.head(10).plot(kind='bar')
plt.title('Top 10 Companies')
plt.xlabel('Company')
plt.ylabel('Number of Job Postings')
plt.xticks(rotation=0)
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(15, 5))
via_count.head(10).plot(kind='bar')
plt.title('Top 10 Platform with highest number of job')
plt.xlabel('Name of the Platform')
plt.ylabel('Number of Job Postings')
plt.xticks(rotation=0)
plt.tight_layout()
plt.show()

# %%
work_from_home = dataframe['work_from_home'].fillna('Not mentioned')
plt.figure(figsize=(15, 5))
plt.pie(work_from_home.value_counts(), labels=work_from_home.value_counts().index, autopct='%1.1f%%')
plt.title('Working from home')
plt.show()
